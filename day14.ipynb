# %% [markdown]
# # day14 of 69 days of python

# %%
# python random numbers

import random

# generate a random integer

print(random.randint(1,20))
# Out:
# 12

# %%
# generate a random float number

print(random.random())
# Out:
# 0.1178672830359897

# %%
# generate random float between range

print(random.uniform(1,5))
# Out:
# 1.231061388961903

# %%
# choose a random elemensts from the list

color = ["red","blue","green","yellow","black","white"]
print(random.choice(color))
# Out:
# red

# %%
# shuffle a list

numbers = [1,2,3,4,5]
random.shuffle(numbers)

print(numbers)
# Out:
# [4, 5, 2, 1, 3]

# %%
# generate random OTP

otp = random.randint(1000,9999)
print(otp)
# Out:
# 8373

# %% [markdown]
# # end day 14 of 69 days of python Everyday_python!
